# %% [markdown]
# #Import the Libraries

# %%
import numpy as np
import pandas as pd 
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv("/content/drive/MyDrive/datafile-1/Reviews.csv",nrows = 100000)

# %%
len(data)
# Out:
# 100000

# %% [markdown]
# # Drop Duplicates and NA values

# %%
data.drop_duplicates(subset=['Text'],inplace=True)#dropping duplicates
data.dropna(axis=0,inplace=True)#dropping na

# %% [markdown]
# # Information about dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88421 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      88421 non-null  int64
#  1   ProductId               88421 non-null  object
#  2   UserId                  88421 non-null  object
#  3   ProfileName             88421 non-null  object
#  4   HelpfulnessNumerator    88421 non-null  int64
#  5   HelpfulnessDenominator  88421 non-null  int64
#  6   Score                   88421 non-null  int64
#  7   Time                    88421 non-null  int64
#  8   Summary                 88421 non-null  object
#  9   Text                    88421 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 7.4+ MB

# %% [markdown]
# #Preprocessing
#
# Here is the dictionary that we will use for expanding the contractions:

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %% [markdown]
# We will perform the below preprocessing tasks for our data:
#
# 1.Convert everything to lowercase
#
# 2.Remove HTML tags
#
# 3.Contraction mapping
#
# 4.Remove (‘s)
#
# 5.Remove any text inside the parenthesis ( )
#
# 6.Eliminate punctuations and special characters
#
# 7.Remove stopwords
#
# 8.Remove short words( eg:  single letters)
#
# Let’s define the function:

# %%
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 

def text_cleaner(text,num):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#call the function
cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t,0))

# %% [markdown]
# Let us look at the first five preprocessed reviews

# %%
cleaned_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
#call the function
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(text_cleaner(t,1))

# %% [markdown]
# Let us look at the first 10 preprocessed summaries

# %%
cleaned_summary[:10]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy',
#  'nice taffy',
#  'great just as good as the expensive brands',
#  'wonderful tasty taffy',
#  'yay barley',
#  'healthy dog food']

# %%
data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary

# %% [markdown]
# #Drop empty rows

# %%
data.replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %% [markdown]
# #Understanding the distribution of the sequences
#
# Here, we will analyze the length of the reviews and the summary to get an overall idea about the distribution of length of the text. This will help us fix the maximum length of the sequence:

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %% [markdown]
# Interesting. We can fix the maximum length of the summary to 8 since that seems to be the majority summary length.
#
# Let us understand the proportion of the length of summaries below 8

# %%
cnt=0
for i in data['cleaned_summary']:
    if(len(i.split())<=8):
        cnt=cnt+1
print(cnt/len(data['cleaned_summary']))
# Out:
# 0.9424907471335922

# %% [markdown]
# 94% of the summaries have length below 8.
# --> maximum length of summary to 8.
#
# Let us fix the maximum length of Text to 30

# %%
max_text_len=30
max_summary_len=8

# %% [markdown]
# Let us select the reviews and summaries whose length falls below or equal to **max_text_len** and **max_summary_len**

# %%
cleaned_text =np.array(data['cleaned_text'])
cleaned_summary=np.array(data['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
df=pd.DataFrame({'text':short_text,'summary':short_summary})

# %% [markdown]
# Remember to add the **START** and **END** special tokens at the beginning and end of the summary. Here, I have chosen **sostok** and **eostok** as START and END tokens
#
# **Note:** Be sure that the chosen special tokens never appear in the summary

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %% [markdown]
# We are getting closer to the model building part. Before that, we need to split our dataset into a training and validation set. We’ll use 90% of the dataset as the training data and evaluate the performance on the remaining 10% (holdout set):

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['summary']),test_size=0.1,random_state=0,shuffle=True)

# %% [markdown]
# #Preparing the Tokenizer
#
# A tokenizer builds the vocabulary and converts a word sequence to an integer sequence. Go ahead and build tokenizers for text and summary:
#
# #Text Tokenizer

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %% [markdown]
# **Remember**:
#
#
# * **tot_cnt** gives the size of vocabulary (which means every unique words in the text)
#
# *   **cnt** gives me the no. of rare words whose count falls below threshold
#
# *  **tot_cnt - cnt** gives me the top most common words
#
# Let us define the tokenizer with top most common words for reviews.

# %%
thresh=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 66.12339930151339
# Total Coverage of rare words: 2.953684513790566

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

# %%
x_tr
# Out:
# array([[ 299,  576, 1490, ...,    0,    0,    0],
#        [  62,    1,  639, ...,    0,    0,    0],
#        [   9,   12,  237, ...,    0,    0,    0],
#        ...,
#        [   3,  282,  236, ...,    0,    0,    0],
#        [  68,  160,  412, ...,    0,    0,    0],
#        [5248,   24,  122, ...,    0,    0,    0]], dtype=int32)

# %%
x_voc
# Out:
# 8440

# %% [markdown]
# #Summary Tokenizer

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %% [markdown]
# Let us define the tokenizer with top most common words for summary.

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

# %% [markdown]
# Let us check whether word count of start token is equal to length of the training data

# %%
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (42453, 42453)

# %% [markdown]
# Here, I am deleting the rows that contain only **START** and **END** tokens

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %% [markdown]
# # Model building
#
# We are finally at the model building part. But before we do that, we need to familiarize ourselves with a few terms which are required prior to building the model.
#
# **Return Sequences = True**: When the return sequences parameter is set to True, LSTM produces the hidden state and cell state for every timestep
#
# **Return State = True**: When return state = True, LSTM produces the hidden state and cell state of the last timestep only
#
# **Initial State**: This is used to initialize the internal states of the LSTM for the first timestep
#
# **Stacked LSTM**: Stacked LSTM has multiple layers of LSTM stacked on top of each other.
# This leads to a better representation of the sequence. I encourage you to experiment with the multiple layers of the LSTM stacked on top of each other (it’s a great way to learn this)
#
# Here, we are building a 3 stacked LSTM for the encoder:

# %%
from keras import backend as K 
from tensorflow.keras.layers import Attention
K.clear_session()

latent_dim = 300
embedding_dim=100

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = Attention()
attn_out= attn_layer([decoder_outputs, encoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30)]         0           []
#
#  embedding (Embedding)          (None, 30, 100)      844000      ['input_1[0][0]']
#
#  lstm (LSTM)                    [(None, 30, 300),    481200      ['embedding[0][0]']
#                                  (None, 300),
#                                  (None, 300)]
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 30, 300),    721200      ['lstm[0][0]']
#                                  (None, 300),
#                                  (None, 300)]
#
#  embedding_1 (Embedding)        (None, None, 100)    844000      ['input_2[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 30, 300),    721200      ['lstm_1[0][0]']
#                                  (None, 300),
#                                  (None, 300)]
#
#  lstm_3 (LSTM)                  [(None, None, 300),  481200      ['embedding_1[0][0]',
#                                  (None, 300),                     'lstm_2[0][1]',
#                                  (None, 300)]                     'lstm_2[0][2]']
#
#  attention (Attention)          (None, None, 300)    0           ['lstm_3[0][0]',
#                                                                   'lstm_2[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 600)    0           ['lstm_3[0][0]',
#                                                                   'attention[0][0]']
#
#  time_distributed (TimeDistribu  (None, None, 8440)  5072440     ['concat_layer[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 9,165,240
# Trainable params: 9,165,240
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
state_h1
# Out:
# <KerasTensor: shape=(None, 300) dtype=float32 (created by layer 'lstm')>

# %% [markdown]
# I am using sparse categorical cross-entropy as the loss function since it converts the integer sequence to a one-hot vector on the fly. This overcomes any memory issues.

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %% [markdown]
# EARLY STOPPING-to stop training the neural network at the right time by monitoring a user-specified metric. Here, WE ARE monitoring the validation loss (val_loss). Our model will stop training once the validation loss increases:

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %% [markdown]
# We’ll train the model on a batch size of 128 and validate it on the holdout set (which is 10% of our dataset):

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 332/332 [==============================] - 270s 769ms/step - loss: 3.2323 - val_loss: 2.8663
# Epoch 2/50
# 332/332 [==============================] - 250s 753ms/step - loss: 2.8837 - val_loss: 2.7309
# Epoch 3/50
# 332/332 [==============================] - 255s 769ms/step - loss: 2.7256 - val_loss: 2.6128
# Epoch 4/50
# 332/332 [==============================] - 253s 761ms/step - loss: 2.6215 - val_loss: 2.5536
# Epoch 5/50
# 332/332 [==============================] - 250s 753ms/step - loss: 2.5463 - val_loss: 2.5747
# Epoch 6/50
# 332/332 [==============================] - 249s 749ms/step - loss: 2.4883 - val_loss: 2.4645
# Epoch 7/50
# 332/332 [==============================] - 259s 781ms/step - loss: 2.4364 - val_loss: 2.4285
# Epoch 8/50
# 332/332 [==============================] - 258s 776ms/step - loss: 2.3954 - val_loss: 2.4139
# Epoch 9/50
# 332/332 [==============================] - 255s 769ms/step - loss: 2.3549 - val_loss: 2.3776
# Epoch 10/50
# 332/332 [==============================] - 252s 758ms/step - loss: 2.3197 - val_loss: 2.3726
# Epoch 11/50
# 332/332 [==============================] - 246s 740ms/step - loss: 2.2891 - val_loss: 2.3445
# Epoch 12/50
# 332/332 [==============================] - 246s 741ms/step - loss: 2.2605 - val_loss: 2.3494
# Epoch 13/50
# 332/332 [==============================] - 249s 751ms/step - loss: 2.2328 - val_loss: 2.3461
# Epoch 13: early stopping

# %%
model.save("/content/drive/MyDrive/datafile-1/my_model")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/datafile-1/my_model/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff445d5a490> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff445f4b810> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff44692d550> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff446bb08d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# #Understanding the Diagnostic plot
#
# Now, we will plot a few diagnostic plots to understand the behavior of the model over time:

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# From the plot, we can infer that validation loss has increased after epoch 17 for 2 successive epochs. Hence, training is stopped at epoch 19.
#
# Next, let’s build the dictionary to convert the index to word for target and source vocabulary:

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %% [markdown]
# # Inference
#
# Set up the inference for the encoder and decoder:

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attention = model.layers[8]
attn_out_inf = attention([decoder_outputs2, decoder_hidden_state_input ])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %% [markdown]
# Let us define the functions to convert an integer sequence to a word sequence for summary as well as the reviews:

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %% [markdown]
# Here are a few summaries generated by the model:

# %%
for i in range(0,10000):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted summary:  great coffee
#
#
# Review: stuff tastes like pink soap gas station bathroom smells yuck threw whole bottle away two tastes took second taste see really tasted bad
# Original summary: horrible taste
# Predicted summary:  not bad
#
#
# Review: chips taste dry gross would rather eat carrots something satisfy salty craving worth calories
# Original summary: overrated
# Predicted summary:  not bad
#
#
# Review: gourmet rice sure especially jasmati still overpriced compared get local works great steamer
# Original summary: good rice kind of pricey
# Predicted summary:  great rice
#
#
# Review: far nastiest thing ever put mouth husband eat anything mean anything even like food go waste could even stomach told take fridge dump entire bottle
# Original summary: yuk
# Predicted summary:  not as good as expected
#
#
# Review: trying quit soda perfect substitute switch great bubbly little drink downside still calories per
# Original summary: delicious and not soda
# Predicted summary:  zico coconut water
#
#
# Review: purchased snack workouts find snacking time really good come variety flavors
# Original summary: good after workout snack
# Predicted summary:  great snack
#
#
# Review: great item described love buying form cost effective divide contents among multiple jars fairly certain mild
# Original summary: great product
# Predicted summary:  great product
#
#
# Review: best peanuts ever worth every penny used subscribe save even better price
# Original summary: the best
# Predicted summary:  best olive oil ever
#
#
# Review: pleased get sausages days prior estimated delivery time beat company used purchase least week sausages shipped original packaging expiration date months another thing never gotten competitors
# Original summary: very prompt shipping
# Predicted summary:  great product
#
#
# Review: youngest wheat free egg free dairy free peanut free diet glad found rice cereal met needs also provided nutrition cheaper purchase amazon purchase local health store
# Original summary: great product
# Predicted summary:  great gluten free pasta
#
#
# Review: love stuff thirst quenching hydrating wish less expensive
# Original summary: refreshing and delicious
# Predicted summary:  great product
#
#
# Review: sauces would highly recommend spices rubs disappoint great flavors anything cooking
# Original summary: great spices
# Predicted summary:  great product
#
#
# Review: christmas gift son loves fruit gems arrived good shape candy fresh real hit christmas morning
# Original summary: sunkist gourmet fruit gems ct lbs
# Predicted summary:  great gift
#
#
# Review: eat taco bell time tastes exactly taco bell sauce included food sold taco bell huge fan chipotle sauce best definitely glad whenever make burritos home
# Original summary: exactly like the real thing
# Predicted summary:  great taste
#
#
# Review: second time buying product believe best value money
# Original summary: best value for your money
# Predicted summary:  great product
#
#
# Review: thing item fruit flies work fly trap would recommend
# Original summary: did not work
# Predicted summary:  good product
#
#
# Review: bought tea mother said tastes great wonders
# Original summary: good tea
# Predicted summary:  great tea
#
#
# Review: way sweet huge fan haribo gold bears real let large sugar overwhelm trace sour yuck
# Original summary: too sweet not sour at all
# Predicted summary:  not good
#
#
# Review: purchased daughter needs avoid gluten texture great like bakery shop coffee cake nice presentation could proud serve guests delicious flavor apricots
# Original summary: delicious and healthy treat
# Predicted summary:  great product
#
#
# Review: order delivery excellent coffee still looking rich good taste coffee find flavor better mountain
# Original summary: still looking for rich good taste coffee
# Predicted summary:  great coffee
#
#
# Review: bought one box six pack sale store cannot believe easy get fiber eat cereal cereals even half much fiber
# Original summary: do not have much fiber
# Predicted summary:  great cereal
#
#
# Review: started taking increase milk supply went back work pump every three hours work making much milk pills work great bad aftertaste anything
# Original summary: effective
# Predicted summary:  works great
#
#
# Review: coffee strong bitter able find ounce stores area ordering online easy love coffee
# Original summary: yuban dark roast ground coffee
# Predicted summary:  great coffee
#
#
# Review: ordered cookies several times best place order nobody sells better price also great tasting cookies everybody know even people eat healthy really like
# Original summary: the best cookie
# Predicted summary:  great cookies
#
#
# Review: ordered coffee themed wedding arrived fight friends smelled tasted good literally hide box wedding big hit wedding day none left put tables great tasting product lowest price seen
# Original summary: great beans
# Predicted summary:  great coffee
#
#
# Review: tastes like poor ranch fav almond barely lime star reviewers eatting anyway soy bold almonds save money calories buy buy extra
# Original summary: where is the lime
# Predicted summary:  not bad
#
#
# Review: third wine kit going fast order another took samples three kits thanksgiving get together heard going finish bottle open another pear
# Original summary: crowd pleaser
# Predicted summary:  great product
#
#
# Review: searching veggie chips forever found farmers market another state years ago searching since chose brand purchase came convient containers taste great wonderful crunch
# Original summary: wonderful
# Predicted summary:  great chips
#
#
# Review: ultra ruined milk healthy product long searched tasty powdered milk substitute product superior flavor easily mixed either cold hot water container tin tightly cap ensure freshness
# Original summary: yummy milk product
# Predicted summary:  great product
#
#
# Review: wonderful tasting syrup great pancakes well ham well worth money
# Original summary: maple syrup
# Predicted summary:  great product
#
#
# Review: sauce awesome sweeter side spectrum defiantly worth try grew bbq sauce still love day
# Original summary: one of the greatest
# Predicted summary:  great sauce
#
#
# Review: crackers good crackers get tasty sized right sturdy enough dipping
# Original summary: some of the best crackers made
# Predicted summary:  great crackers
#
#
# Review: favorite cup coffee easy drink smooth yet nice character without bitterness similar character favorite caffe verona familiar large coffee chain
# Original summary: smooth yet flavorful similar to verona
# Predicted summary:  great coffee
#
#
# Review: product used two sons two good neighbors buying locally small bottles seller provides good service
# Original summary: bitters
# Predicted summary:  great product
#
#
# Review: zoom bottom left box list ants product work bad info web description may fine every kind ant almost wasted money
# Original summary: not all ants
# Predicted summary:  not what expected
#
#
# Review: first things delicious however opening without making mess nearly impossible super crumbly open package care buy many good options way less messy
# Original summary: delicious but messy
# Predicted summary:  great product
#
#
# Review: said say best addicted funny love single serving bags far orginal favorite friends love bbq ones salt vinegar orginal ones favorite thank popchips
# Original summary: popchips
# Predicted summary:  best ever
#
#
# Review: great find someplace could buy nice quantity great price
# Original summary: my husband loves this tea
# Predicted summary:  great product
#
#
# Review: lower fat calories chips seem satisfy better regular chips try like em
# Original summary: you have gotta try these
# Predicted summary:  great chips
#
#
# Review: tea full bodied fruity taste brew strong iced tea sweeten splenda similar appearance taste red wine since nasal allergy alcohol stumbled upon acceptable substitute
# Original summary: excellent refreshing tea
# Predicted summary:  great tea
#
#
# Review: best thing ive tasted long time great period going school work wanting snack
# Original summary: love it
# Predicted summary:  great flavor
#
#
# Review: found product expo daughter loved much needed order refills one week later definitely must college
# Original summary: hot waffles in the microwave
# Predicted summary:  great product
#
#
# Review: best taste pasta cooks well slightly less time typical mass produced pasta nice color excellent
# Original summary: wow excellent
# Predicted summary:  great product
#
#
# Review: best hot cocoa cup taste smooth creamy perfect cold morning evening hot drink would definitely recommend product best part ordered auto delivery never run
# Original summary: delicious hot cocoa
# Predicted summary:  best hot cocoa ever
#
#
# Review: dog loves fairly reasonable price like purchase may bags keep fresh purchase
# Original summary: good treat
# Predicted summary:  great dog treats
#
#
# Review: cookies great kids snacks adults careful little get hand ate half box snacking watching tv one night plus auto ship great bargain
# Original summary: taste like graham crackers
# Predicted summary:  great cookies
#
#
# Review: great tea better price tea becoming hard find stores live
# Original summary: full of win
# Predicted summary:  great tea
#
#
# Review: used ham base loaded msg realize ordered return food item
# Original summary: msg ham base
# Predicted summary:  good product
#
#
# Review: nutty flavor good bite versatile tried stand alone side yet add soup stew pretty satisfying filling meal great flavor
# Original summary: good flavor nice blend
# Predicted summary:  great taste
#
#
# Review: moved salted fish best ever favourite dishes
# Original summary: must have it
# Predicted summary:  great product
#
#
# Review: strong coffee right price one cups work well cups lot less money
# Original summary: perfect coffee
# Predicted summary:  great coffee
#
#
# Review: tried different brands coconut water favorite coconut water splash pineapple favorite flavor wish price would come back absolutely love stuff
# Original summary: best ever
# Predicted summary:  great taste
#
#
# Review: fewer fewer stores carry loose leaf tea glad find amazon knew become avid fan amazon last months wonderful someone else shopping allows find products one place
# Original summary: lipton loose leaf tea
# Predicted summary:  great tea
#
#
# Review: chips crisp good think order well
# Original summary: prpduct was ok but
# Predicted summary:  great chips
#
#
# Review: thanks gummis didnt arrive big clump thought would also came right time thanks
# Original summary: gummis
# Predicted summary:  great gift
#
#
# Review: flavors subtle great tot introduced healthy veggies added half jarred organic pasta sauce gave sweet mild taste kids loved
# Original summary: my kids loved it
# Predicted summary:  great for our kids
#
#
# Review: taste super good single bad ingredient snack away feel good
# Original summary: excellent item
# Predicted summary:  not good
#
#
# Review: would save money look better neither husband cared kind like chewing hard waffle buying
# Original summary: these are not very good
# Predicted summary:  not what expected
#
#
# Review: know product good true half calories regular pasta wow
# Original summary: fabulous product
# Predicted summary:  great product
#
#
# Review: orchid arrived within days ordered perfectly packaged healthy please remember take two years mature flowering mine month half beautifully
# Original summary: beautiful little seedling
# Predicted summary:  great product
#
#
# Review: ordered product weeks ago beef jerky hard tear chew like rubber took forever would buy kind disappointed
# Original summary: is below par very hard to chew
# Predicted summary:  not good
#
#
# Review: tasty bit ordinary nice able get
# Original summary: tasty
# Predicted summary:  delicious
#
#
# Review: tried party found tasty kind oily though
# Original summary: taste very good
# Predicted summary:  good but
#
#
# Review: love dry rubs sister sent us try hooked peppery sweet goes anything grill new favorite
# Original summary: willinghams rub
# Predicted summary:  great product
#
#
# Review: husband tried six different varieties coffee tassimo care actually thought machine problem tried brand blend loves actually weak like really strong cup
# Original summary: my husband favorite
# Predicted summary:  good coffee
#
#
# Review: wonderful aroma taste goes smooth add little honey drops lemon concentrate delicious cups day moderation
# Original summary: my favorite tea
# Predicted summary:  best ever
#
#
# Review: tasting tetley side side flavor costs tetley tetley british blend premium black count tea bags let tea steep long time get bitter tetley
# Original summary: tetley is cheaper and tastes the same
# Predicted summary:  great taste
#
#
# Review: ice tea like heaven ice must try love lemon great price content make pitcher bags add lemon whatever sweetner prefer great barbeque parties tea ladies
# Original summary: ice tea
# Predicted summary:  best tea ever
#
#
# Review: great product would never free wife gluten free would cook two different meals eat gluten free also look product stores order line great
# Original summary: sam mills gluten free pasta
# Predicted summary:  gluten free flour
#
#
# Review: never tried lara bars loved seller speedy efficient
# Original summary: great product
# Predicted summary:  great product
#
#
# Review: unfortunately got bad batch box apparently old hard nearly break teeth bite eaten nearly every flavor kind bars know suppose taste like flavored bricks stale
# Original summary: stale
# Predicted summary:  not bad
#
#
# Review: new fav great flavor acid great love comes containers also good buy
# Original summary: fantastic robust flavor
# Predicted summary:  great taste
#
#
# Review: love tea drink day long find comforting satisfying especially pleasant cool day
# Original summary: mellow satisfying tea
# Predicted summary:  great tea
#
#
# Review: fresh find watermelon often store cost per pc cents love
# Original summary: yum
# Predicted summary:  great product
#
#
# Review: love smaller size cans cats eat one sitting quality seems high cats love know picky eaters husband commented looked like people food think good product would buy
# Original summary: our cats love these petite cuisine meals
# Predicted summary:  cat loves these
#
#
# Review: much product good preferred preparation directions product previously bought using prior yogurt product next time order
# Original summary: product ok
# Predicted summary:  great product
#
#
# Review: bamboo arrived weeks ordering intact well packed however instructions caring bamboo almost month since arriving part bamboo looks like dying turning brown would buy company shipping costly
# Original summary: heart shaped lucky bamboo
# Predicted summary:  great product
#
#
# Review: dog likes treats keep laundry room everytime go laundry head box give treat hard treats kind big probably would good tiny dogs miniature schnauzer pounds right size
# Original summary: dog likes them
# Predicted summary:  my dog loves these
#
#
# Review: quality bones buying going hill decided try love cut half great dog treat last much longer bones purchasing keep buying dogs hope quality stays keep good product price right
# Original summary: great bones
# Predicted summary:  great for training
#
#
# Review: liked almonds dusted chocolate plastic like sheen cheap chocolate many chocolate almonds true description cocoa roast loved based quickly disappeared everyone else
# Original summary: delicious
# Predicted summary:  not bad
#
#
# Review: let bad reviews fool sour delicious fact gave one son gobbled even asked another definitely buy
# Original summary: these are great
# Predicted summary:  great product
#
#
# Review: used buy pasta regularly local supermarkets years ago vanished glad upon amazon transaction usual perfectly fine
# Original summary: fave
# Predicted summary:  great product
#
#
# Review: stars product target amazon sell cashews lower price okay add sales tax price difference still buy target better price even including sales tax
# Original summary: decent price
# Predicted summary:  price
#
#
# Review: pops well air popper decent flavor fast ship good value could ask anything
# Original summary: solid choice for popcorn
# Predicted summary:  popcorn
#
#
# Review: cat goes completely insane stuff even hearing bag eyes turn large pure black definitely step stuff available target knew cat also like processed food much
# Original summary: cat crack
# Predicted summary:  cat loves these
#
#
# Review: hey great breakfast combo along juice milk tea coffee also filling trust believe try let tell told
# Original summary: all you need
# Predicted summary:  great tea
#
#
# Review: theses okay durable thought little stick able chew edges
# Original summary: ok for chewers
# Predicted summary:  not bad
#
#
# Review: kicked coffee habit one year ago drinking uncle white tea first tea cause allergic reaction find delicious local supermarket stopped handling tea thank heavens buy line
# Original summary: uncle lee white tea
# Predicted summary:  great tea
#
#
# Review: loved didnt airbrush real good painted came beautiful couple coats though
# Original summary: love it
# Predicted summary:  great product
#
#
# Review: love oatmeal handy store good eat easy take running late work going town evening snack
# Original summary: oatmeal
# Predicted summary:  great cereal
#
#
# Review: tuna flavor never fails entice cats eat matter often temptations gets thumbs best treat found meets full nutritional needs well
# Original summary: favorite treat
# Predicted summary:  my cat loves these
#
#
# Review: company products best caffeine free makes feel good live stuff drink whole day work everyday
# Original summary: love this stuff
# Predicted summary:  great product
#
#
# Review: definately chihuahua puppy approved like fact puppy food smaller breeds real small bites puppy lbs weeks tiny something small enough chew months old still enjoys
# Original summary: chihuahua puppy approved
# Predicted summary:  my dog loves these
#
#
# Review: celestial seasonings chai tea best brand ever tasted chai enjoy evening glad make decaf none local stores carry anymore pleased able order amazon shipping makes best deal ever
# Original summary: best chai ever
# Predicted summary:  best chai tea
#
#
# Review: snacking crackers line long time someone suggested try sticks twigs love everything love crunch texture course love taste especially curry flavor delicious also nutricious lots protein fiber make perfect snack
# Original summary: my new favorite snack
# Predicted summary:  great crackers
#
#
# Review: one best world first tried salt scotland buying ever since worth price
# Original summary: best of britain
# Predicted summary:  great product
#
#
# Review: seven year old cairn terrier puppy happy dance likes bacon peanut butter break half save calories
# Original summary: happy dance
# Predicted summary:  my dog loves these
#
#
# Review: two dogs love product organic newman dog foods good dog give try keep good health
# Original summary: must for dogs
# Predicted summary:  great product
#
#
# Review: ride miles weekends really enjoy great taste energy gives break ride
# Original summary: great taste and energy
# Predicted summary:  great product
#
#
# Review: great flavor bit bitter bite longer sits better taste number one choice
# Original summary: san francisco fog chaser
# Predicted summary:  great taste
#
#
# Review: absolutely love honey stinger products tried date incredibly tasty leave chalky otherwise aftertaste energy even end long ride great energy bars great price quantities
# Original summary: very tasty and full of energy
# Predicted summary:  great taste
#
#
# Review: one cat sensitive stomach hairball problems tried quite treats one give come back
# Original summary: works for my cat
# Predicted summary:  cat loves these
#
#
# Review: winner haribo frogs favorite large bag little harder toward end frogs started getting little tough solved soon opened next one delicious
# Original summary: delicious
# Predicted summary:  best ever
#
#
# Review: gluten free want crackers one also delicious second order
# Original summary: cracker of cracker
# Predicted summary:  great gluten free cookies
#
#
# Review: goodness love mustard jar currently going amazon com much hard find stores anywhere mustard excellent nothing touches
# Original summary: favorite
# Predicted summary:  best ever
#
#
# Review: love chunky chews rawhide ring rawhide chews assumed one would good much dog got half thing hour throwing night recommend going something would last longer
# Original summary: highly disappointing
# Predicted summary:  my dog loves these
#
#
# Review: took stuff nothing maybe little bit alert energy let two friend try nothing also buyer beware buy bottle wal mart consider case
# Original summary: nothing
# Predicted summary:  not what expected
#
#
# Review: popcorn delicious however packages oily thus make put popcorn maker task
# Original summary: delicious
# Predicted summary:  great popcorn
#
#
# Review: basset granulated garlic hands better using years consistantly best
# Original summary: and basset is just hands down better
# Predicted summary:  great product
#
#
# Review: tasty easy use pod little expensive price
# Original summary: very good tea
# Predicted summary:  great product
#
#
# Review: taste great true reviewers said consistency good sticking teeth however energy boost running thing fact actually cause eat whenever feel need sugary fix
# Original summary: tasty
# Predicted summary:  great product
#
#
# Review: product reasonable price compared stores taste good stop eating rice switch bulgur high fiber fruits vegetables added stronger healthier ever certainly recommend product anyone give try
# Original summary: roland bulgur
# Predicted summary:  great product
#
#
# Review: ryvita still within best enjoyed date crisp put oven crisp however purchased reduced price future purchases shall wary sale items love ryvita though love order coming door quickly
# Original summary: crispbread
# Predicted summary:  great product
#
#
# Review: since drink much tea buy best smooth never bitter always make sure stocked pantry
# Original summary: tea for the summer
# Predicted summary:  great tea
#
#
# Review: dust really worked stop tomato worms eating pepper tomato plants figured use simple hold flat puff would helpful
# Original summary: little puff will do ya
# Predicted summary:  great product
#
#
# Review: bought food bought several flavors previously however particular flavor agree dog system said cannot say enough good things natural balance company
# Original summary: food but not good for my dog
# Predicted summary:  my dog loves it
#
#
# Review: terrific seasoning kinds meat may even try fish used beef burritos chicken enchiladas tacos etc everytime use family friends love ask recipe
# Original summary: family pleaser
# Predicted summary:  great seasoning
#
#
# Review: bought sea travel relieve nausea found works great sore throat cold symptoms easy use tastes good like fact drink hot cold
# Original summary: great multipurpose product
# Predicted summary:  great product
#
#
# Review: received order timely manner however chips expired april would waste time return item rest assured hope product review next interested buyer definately worth hassle
# Original summary: buyer beware
# Predicted summary:  not as expected
#
#
# Review: particular flavor favorite strong bitter prefer flavor
# Original summary: it is ok
# Predicted summary:  great taste
#
#
# Review: far favorite olive excellent dips dressings
# Original summary: best olive oil ever
# Predicted summary:  best olive oil ever
#
#
# Review: dog thinks crack crazy teenie arived time cheeper store sure would recomend
# Original summary: love it
# Predicted summary:  great dog treats
#
#
# Review: licorice good taste daughter gluten free diet loves cherry bites
# Original summary: candy tree organic cherry bites
# Predicted summary:  great
#
#
# Review: great deal first bought dog loves treats serve great training
# Original summary: my dog loves these
# Predicted summary:  great treats
#
#
# Review: tastes like tropical cocktail needs alcohol mango flavor pungent like flavor like tea enjoyable taste
# Original summary: tastes great
# Predicted summary:  delicious
#
#
# Review: tried coffee wonderful smooth rich full flavored bold would recommend anyone
# Original summary: great coffee
# Predicted summary:  great coffee
#
#
# Review: love mainstream works like bisquick recipes work regular bisquick though wish recipes available taste gluten free options
# Original summary: works like bisquick
# Predicted summary:  great product
#
#
# Review: flavor great thought person bought gave back
# Original summary: think thin bar
# Predicted summary:  great taste
#
#
# Review: container good size keep raisins fresh raisins taste good exactly expect organic raisins eat every morning oatmeal makes happy
# Original summary: perfect raisins
# Predicted summary:  great product
#
#
# Review: surprised taste powdered peanut butter creamy told powder mixed water could tell difference draw back eat mixed tried make little extra later consistency changed prepare amount plan consuming good
# Original summary: smooth nutty taste
# Predicted summary:  refreshing
#
#
# Review: subscribe save option much cheaper per box local stores open box discover flavor treats puppy complaining bit
# Original summary: great savings
# Predicted summary:  great product
#
#
# Review: want add kick food try product delicious though little goes long way
# Original summary: hot hot hot
# Predicted summary:  great product
#
#
# Review: excellent cook serve fat free pudding good watching weight yet tastes good enough serve guests
# Original summary: tapioca pudding
# Predicted summary:  great product
#
#
# Review: delivered great healthy sub potato chips snack bags perfect size great crunch enjoy flavors
# Original summary: pop chips rock
# Predicted summary:  pop chips
#
#
# Review: annie organic beef skillet meal ounce boxes one best quick beef stroganoff meals love fact yummy good without preservatives yeah annie
# Original summary: annie homegrown organic beef stroganoff skillet meal
# Predicted summary:  great product
#
#
# Review: shared dr lucy cookies amazed taste never healthy cookie crunchy like eating homemade cookie made love took mother love create amazing cookies looking forward flavors thanks dr lucy
# Original summary: cookie cravings
# Predicted summary:  great cookies
#
#
# Review: could find whole cardamom local supermarkets ethnic markets far luckily found whole cardamom perfect first time ordered spice online admit felt bit odd first experience would hesitate
# Original summary: yum delicious cardamom
# Predicted summary:  great product
#
#
# Review: never tried tea keurig happy flavor good way start day warm cup mid afternoon
# Original summary: this tea is delicious
# Predicted summary:  great tea
#
#
# Review: amount kefir grains tiny ended might fine patience grow wanted teaspoons kefir
# Original summary: not helpful amount of kefir
# Predicted summary:  great product
#
#
# Review: chips fabulous crunchy remind cape cod chips lot expensive definetly worth price
# Original summary: fabulous chips
# Predicted summary:  great chips
#
#
# Review: fantastic like crystallized ginger hard spicy usda organic bit ginger day good eat least couple pieces day also good nausea
# Original summary: great snack
# Predicted summary:  great flavor
#
#
# Review: accidentally bought chips say little tart seem eating quickly like taste vinegar like
# Original summary: makes you pucker but tastes good
# Predicted summary:  great chips
#
#
# Review: great product try looking good substitute fiji water cleanest taste truly believe story behind really glad gave try thanks destiny
# Original summary: great water
# Predicted summary:  great product
#
#
# Review: coffee smooth enjoy much continue purchase good pecan cookie
# Original summary: kona blend
# Predicted summary:  great coffee
#
#
# Review: time time try coffees kicks always go back sumatra unbelievable earthy bold taste die
# Original summary: cannot live without sumatra
# Predicted summary:  great coffee
#
#
# Review: great coffee flavor great price like method use coffee canister store open package use subscription even better price
# Original summary: great way to make cup coffee
# Predicted summary:  great coffee
#
#
# Review: really enjoy jalapeno flavor wasabi flavor step behind lime chili flavor think would enjoy beer lime flavor way intense ordering flavor
# Original summary: limey
# Predicted summary:  not bad
#
#
# Review: almost identical great chocolate taste raw organic best also whip whipped sprouted almonds make ball snacks yumm
# Original summary: outrageous
# Predicted summary:  delicious
#
#
# Review: used blender make great cereal oatmeal chemical taste good price hard find item
# Original summary: good stuff
# Predicted summary:  cereal
#
#
# Review: shopping around box oatmeal come find going hit buy neighborhood costco box makes box rip double price
# Original summary: over prices item
# Predicted summary:  great product
#
#
# Review: brand got mine bin hardly anything since learned rarely come cheap seriously good beans best taste like
# Original summary: my favorite bean
# Predicted summary:  great coffee
#
#
# Review: best hazelnut coffee ever tasted drink daily house love buy amazon see
# Original summary: puck hawaiian hazelnut coffee at amazon com
# Predicted summary:  great coffee
#
#
# Review: keep trying brands cheaper brands stupid ginger soooo worth money tender moist never let
# Original summary: simply the best
# Predicted summary:  great product
#
#
# Review: cats actually think getting treat give pills pockets even beg sure beats pills throats
# Original summary: cats think pills are treats
# Predicted summary:  cat loves these
#
#
# Review: normally love chips buy large bags individual bags tasted totally different makes sense bought large bags tasted great
# Original summary: pretty bad
# Predicted summary:  pop chips
#
#
# Review: gluten free pasta best ever tried many brands like taste brand delicious well worth price
# Original summary: delish
# Predicted summary:  best gluten free pasta
#
#
# Review: use tablespoon time wash dishes soap dispenser fill rest dishwasher soap since took dishwasher detergent clean worth darn use something else glasses cloudy film dishwasher looks like brand new
# Original summary: great when have hard water
# Predicted summary:  great product
#
#
# Review: know affects weight taste tea wonderful soft earthy light berry flavor wonderful
# Original summary: wonderful berry taste
# Predicted summary:  great tea
#
#
# Review: water good touch sweet helps drink even without sugar love
# Original summary: wonderful
# Predicted summary:  zico coconut water
#
#
# Review: one hot extract use drop bowl soup makes plenty hot also use heat chili like hot top cannot taste food final answer looking
# Original summary: the final answer oh yeah
# Predicted summary:  great product
#
#
# Review: bread moist flavorful however ordered pack arrived every single dented people buy product long term storage definitely problem probably buy bread future purchase another vendor
# Original summary: dented cans
# Predicted summary:  great product
#
#
# Review: would give stars would leave seasoning going eat tablespoons seasoning want pay certainly want sift seasoning get little pieces end overall taste excellent light crunch seasoning taste good much
# Original summary: too much seasoning
# Predicted summary:  great product
#
#
# Review: older dog arthritis right hip good recommendations purchased loves retriever younger given also
# Original summary: great for all dogs
# Predicted summary:  great for training
#
#
# Review: aluminum free hard find local supermarket reason happy find much decent price happy
# Original summary: baking fun
# Predicted summary:  great product
#
#
# Review: chihuahuas love greenies get let know part routine know
# Original summary: doggie dope
# Predicted summary:  great treat
#
#
# Review: price great variety flavor good baby likes takes eat safe clean leave refrigerator
# Original summary: complete breakfast
# Predicted summary:  great product
#
#
# Review: using soap year makes skin feel clean never go back using soaps added make skin feel dry tight favorite soap
# Original summary: olivella soap
# Predicted summary:  great product
#
#
# Review: point life due health concerns going away processed foods trying buy organic whenever amazon making easy olive oil purchase item subscribe save becomes price non organic grocery store definately purchase
# Original summary: affordable organic olive oil
# Predicted summary:  great product
#
#
# Review: one expect black truffle paying price winter truffle cheap reason taste smell disappointed tried truffle realized price reason least used add colour dish
# Original summary: no taste no smell
# Predicted summary:  great product
#
#
# Review: really enjoy drink works great nice calming effect great hard day work
# Original summary: really works
# Predicted summary:  great product
#
#
# Review: tastes good little sweet first thought lot sugar looked box surprised much
# Original summary: good hot cocoa
# Predicted summary:  good taste
#
#
# Review: husband love chips personally think flavor perfect try
# Original summary: yum
# Predicted summary:  great chips
#
#
# Review: helps dog sensitive stomach stools adds nutrition time add tsp feeding pound dog
# Original summary: great to add to pet food
# Predicted summary:  great dog food
#
#
# Review: far canned soups go ok disappointed texture extra unexpected bits overall quality spoiled living maine years south tried different brands canned bisque come lobster bisque best made fresh
# Original summary: as far as canned soups go
# Predicted summary:  great product
#
#
# Review: green mountain one favorite coffee brands breakfast blend mellow great way start day
# Original summary: mellow coffee
# Predicted summary:  great coffee
#
#
# Review: favorite hot beverage years disappointed longer sold local grocery store given finding ran across amazon coffee flavor chocolate like mocha like stronger directions sometimes mix hot chocolate yumm
# Original summary: love this italian cappuccino mix
# Predicted summary:  best coffee ever
#
#
# Review: coffee price fantastic delivery right point recommended offer friends family jumped right got delivery first
# Original summary: luv my cups
# Predicted summary:  great coffee
#
#
# Review: pretty good coffee little bitter strong coffees price great though worth order
# Original summary: pretty worth it
# Predicted summary:  great coffee
#
#
# Review: ok cooking tried yogurt disolve well use cooking milk somewhat dissapointed
# Original summary: ok for cookiing
# Predicted summary:  great product
#
#
# Review: good liver concerns really potent excellent anti oxidant helps liver get rid excess iron also flouride chemicals makes clean product would recommend
# Original summary: green tea extract on the market today
# Predicted summary:  great product
#
#
# Review: really high quality cinnamon good consistency strong flavor evenly ground organic ceylon buy highly recommended
# Original summary: delicious cinnamon
# Predicted summary:  great product
#
#
# Review: buy local grocery store get least days sooner less stress
# Original summary: do not use this company
# Predicted summary:  great product
#
#
# Review: supposedly helps control weight know fine cooking oil smoky olive oil taste well would expect fine oil bought bottle set twice highly recommend cooking
# Original summary: safflower oil
# Predicted summary:  great product
#
#
# Review: much say quaker oatmeal bigger box would get grocery store problem plain box clearly knew bought wish offered big box without plain flavor
# Original summary: just as expected
# Predicted summary:  good product
#
#
# Review: brown lentils actually difficult find grocery store much better quality anyway bigger end product tastes better run mill grocery store lentils reviewer gave subpar review due bag directions google friend
# Original summary: unmatched quality
# Predicted summary:  great product
#
#
# Review: literally almost throw everytime open bag figured would give shot natural blah blah blah dog seem care treat difference treats make gag sticking beggin strips
# Original summary: they smell horrible
# Predicted summary:  horrible
#
#
# Review: one best pastas ever eaten family like better every pasta tried gluten free otherwise highly recommended
# Original summary: best pasta out there
# Predicted summary:  best gluten free pasta
#
#
# Review: baby like much think salmon delicious salmon good food make baby happy
# Original summary: good
# Predicted summary:  great for our baby
#
#
# Review: jimmies purple mix exactly looking since planning eating know taste color excellent
# Original summary: exactly what wanted
# Predicted summary:  great product
#
#
# Review: dogs love dogs cookies cannot imagine buying anything else love price free shipping life good
# Original summary: best dog treats
# Predicted summary:  great treats
#
#
# Review: pleased light crispy texture sweet taste far best gf oatmeal cookie found traditional chewy oatmeal texture still great even better available amazon
# Original summary: light and crispy cookie
# Predicted summary:  delicious
#
#
# Review: tried several different kinds gluten free crackers something similar saltine favorite choice kids really liked cheese crackers crumble chili soups problem arrive broken usually seperate crumbled ones save ziploc soups
# Original summary: best substitute we have found
# Predicted summary:  great gluten free alternative
#
#
# Review: well get energy really want hours really bit calm need rest bad great product
# Original summary: great product
# Predicted summary:  great product
#
#
# Review: barley described ordered price right product good buy store without driving traffic
# Original summary: pearled barley
# Predicted summary:  great product
#
#
# Review: first love american section supermarket love goya products decided going pick package delicious perfect amount sweetness mention cents amazing
# Original summary: goya palmeritas
# Predicted summary:  great product
#
#
# Review: pudge free brownies recommended us pair excellent substitute real thing take care craving dessert sweet time hurt low fat diet try baking oven different taste sensation
# Original summary: excellent substitute for the real thing
# Predicted summary:  great product
#
#
# Review: selling much selling per price pack
# Original summary: what
# Predicted summary:  price
#
#
# Review: happy purchased put morning green smoothies addition drinking throughout day prefer taste regular bagged green tea also use make home made mochi
# Original summary: delicious nutritious
# Predicted summary:  great product
#
#
# Review: thrilled pick tiny bits gravel flax seeds fine top quality gravel bits would get stars
# Original summary: good seeds but gravel bits
# Predicted summary:  great product
#
#
# Review: maxwell house filter packs great idea people moving fast morning four cups pack gone recently supermarket shopped discontinued de caf version product found amazon order ever since
# Original summary: maxwell house de caf filter packs
# Predicted summary:  great product
#
#
# Review: agree reviewer think cereal marshmallows gross never liked teddy grahams much anyway
# Original summary: fake and gross
# Predicted summary:  yuck
#
#
# Review: tetley round family size ice tea bags perfect complement mr coffee ice tea machine like fresh tea taste get use tetley
# Original summary: great complement for my ice tea machine
# Predicted summary:  great tea
#
#
# Review: first found treats cosco could find costco time went amazon found pets love wife also loves
# Original summary: fantastic
# Predicted summary:  great treats
#
#
# Review: dog loves teeth stay clean vet always amazed still great teeth amazon offered best price fast shipping
# Original summary: petrodex dental chews
# Predicted summary:  great dog treat
#
#
# Review: think great best surprise ever bought could eat right jar mostly eat alone whole wheat bread kraft mayo olive oil cracked pepper ounce
# Original summary: love it
# Predicted summary:  great product
#
#
# Review: fried rice mix son husband eat checking every supermarket town finding kikkoman time order fried rice three times first two weeks arrived
# Original summary: the best
# Predicted summary:  great for the go
#
#
# Review: sure negative reviews maybe date best figs alot better sunmaid many times contains alot ripe figs right bad local kroger stopped carrying highly recommended
# Original summary: great
# Predicted summary:  great product
#
#
# Review: read reviews purchasing received mini sprouter tried start using water keeps leaking sides sure could wrong since pieces stack disappointing returning asap
# Original summary: umm why wont the water stay in
# Predicted summary:  not for me
#
#
# Review: like ginger food taste like lemon ginger peppery punch taste strong think would better poured cabbage soup base
# Original summary: really strong flavor
# Predicted summary:  not ginger
#
#
# Review: sent weather still managed get one piece without melting used baby shower everyone loved would definitely recommend
# Original summary: yummy and pretty
# Predicted summary:  great product
#
#
# Review: kitty loves treats cannot get enough loves much friend mine kitty also gave kitty kitty addicted
# Original summary: cat treats
# Predicted summary:  great treats
#
#
# Review: taste strong hard candies last melt mouth plenty bag last like butterscotch real deal
# Original summary: very tasty and convenient
# Predicted summary:  good but
#
#
# Review: love coffee bitterness lots good coffee taste one fits bill holds well milk sugar love morning first cup evening much definitely would buy
# Original summary: good medium strength coffee
# Predicted summary:  great coffee
#
#
# Review: macaroons taste fantastic raw merry advertising product raw six ingredients two raw coconut oil sea salt raw ingredients product see back package details
# Original summary: this product is not raw
# Predicted summary:  good product
#
#
# Review: taste slightly different remember fig newtons little surprised first seemed maybe little like grew addicting
# Original summary: addicting
# Predicted summary:  good but not great
#
#
# Review: like coffee prefer community breakfast blend one one strong coffee much better seattle best coffee bought ran community coffee really like brand coffee keep buying brand
# Original summary: coffee but like the breakfast blend better
# Predicted summary:  great coffee
#
#
# Review: using turmeric powder years read beneficial many health problems prevention way whenever possible possibilities least try control health care tasteless add nice color eggs
# Original summary: beneficial
# Predicted summary:  great product
#
#
# Review: tried recommendation guy liquor store said smooth man right favorite whiskey love
# Original summary: smoothest whiskey
# Predicted summary:  great product
#
#
# Review: dog really enjoys treats plus help keep teeth clean definatly purchase
# Original summary: great dog treat
# Predicted summary:  great treats
#
#
# Review: great product quick shipping dog really loves food allergic wheat none picky eater loves food
# Original summary: picky dog
# Predicted summary:  great treats
#
#
# Review: dog finicky eater chef michael actually eats whole bowl food everyday never used made high quality ingredients packaged really well probably best dog food come across far
# Original summary: have to get more of this food
# Predicted summary:  great dog food
#
#
# Review: grew stuff spent countless hours searching grocery stores thank goodness amazon stay stocked sunday morning pancakes back
# Original summary: childhood fave
# Predicted summary:  great product
#
#
# Review: food great quality cats love cats enjoy food would highly recommend made quality ingredients
# Original summary: wellness canned cat food tuna
# Predicted summary:  cat food
#
#
# Review: favorite coffee cup every day cinnamon flavor powering cinnamon scent fills really taste like cinnamon roll hints like flavored coffees mild love cinnamon flavor coffee
# Original summary: cinnamon roll cup
# Predicted summary:  great coffee
#
#
# Review: love peanut butter taste particularly like chocolate either rather bland neither kids liked gave rest friend like either
# Original summary: yuck
# Predicted summary:  not bad
#
#
# Review: smelling spice way overpriced amount get use dishes including non sniff
# Original summary: addictively smelling spice
# Predicted summary:  great product
#
#
# Review: closest thing real crackers going find gluten free world cannot real thing buy
# Original summary: best gluten free crackers ever
# Predicted summary:  great gluten free cookies
#
#
# Review: disappointed coffee gave several cups family use one liked tried using small cup large cup size still bitter funny aroma
# Original summary: worst coffee ever
# Predicted summary:  good coffee
#
#
# Review: duck fat unique ability put underlying flavor makes friends eyes say make dish soo much better find smaller amount must buy amount freezes problems buy share fat knowledge friends thank
# Original summary: just better than butter
# Predicted summary:  great for the go
#
#
# Review: good tasting pricing pretty good always sold keurig com come make purchase love dark chocolate reason stars pricing great okay
# Original summary: another yummy
# Predicted summary:  great taste
#
#
# Review: daughter makes popcorn whirly pop agree best popcorn ever medium sized kernels flavorful
# Original summary: amish country lady finger popcorn
# Predicted summary:  great popcorn
#
#
# Review: bought two large bags amazon shipment took worth wait haribo far favorite gummy maker
# Original summary: yum
# Predicted summary:  great
#
#
# Review: daughter loves chex food take work snack eats time like way fits bag
# Original summary: chex food
# Predicted summary:  great snack
#
#
# Review: well really think tasted much like pumpkin chocolate around delicious think may buy plain chocolates next time
# Original summary: pumpkin chocolate
# Predicted summary:  great candy
#
#
# Review: three dogs chew lot wanted find something would last longer minutes ordered also elk moose antler dogs still chewing today actually bella working elk typing order gone soon
# Original summary: loooooong lasting
# Predicted summary:  dogs love it
#
#
# Review: cans labeled like hummus think mislabeled wanted hummus ok add olive oil garlic lemon juice ending decent hummus
# Original summary: it is not babaganouge
# Predicted summary:  not what expected
#
#
# Review: trying eat healthier one things really love chips salty snacks kinds popchips really trick satisfying craving though really care pepper flavor like others buy
# Original summary: popchips satisfy my salt and crunch craving
# Predicted summary:  great snack
#
#
# Review: hubby prefers maxwell house today prices need watch bargains jars cheaper jars local mart store grocery store say money saved spent stuff fav website lol
# Original summary: coffee
# Predicted summary:  great product
#
#
# Review: grew kraft mac cheese shells cheese different enjoyed eaten pasta im even looking order
# Original summary: cheeselicious
# Predicted summary:  good
#
#
# Review: bought bunch mom make persian ice cream received time package
# Original summary: good noodles
# Predicted summary:  great product
#
#
# Review: silk pure almond tasty alternative soy rice milk thicker rice milk creamy soy milk taste would expect either nutty tasting mixes well anything usually use morning cereal
# Original summary: tasty alternative to soy or rice milk
# Predicted summary:  love this rice
#
#
# Review: good product thankful shipped rural alaska couple due freezing weather retailer fault happy sort carbonated beverage
# Original summary: thanks for shipping
# Predicted summary:  great product
#
#
# Review: hard find great tasting gluten free soup found great add lean beef vegetable soups makes cooking lot easier tastes better campbell mushroom soup cheaper amazon sure
# Original summary: great tasting soup gluten free
# Predicted summary:  great gluten free pasta
#
#
# Review: love make deep dish pizza breadsticks loaf bread grilled cheese tomato sandwiches never tasted good use garlic olive oil oil
# Original summary: can have pizza
# Predicted summary:  great product
#
#
# Review: year old pug eat anything unfortunately would go near matter hard tried peak interest
# Original summary: not so much
# Predicted summary:  not my dog loves these
#
#
# Review: german shepherd puppy loves food soft mixes dry food easily ingredients fantastic know eating quality food
# Original summary: great puppy food
# Predicted summary:  my dog loves these
#
#
# ...
# Original summary: great doggie treat
# Predicted summary:  great product
#
#
# Review: happy product tastes really yummy lots extra ingredients love variety ella products baby getting lots healthy foods one meal also easy squeeze onto spoon feed mess
# Original summary: tastes good
# Predicted summary:  great product
#
#
# Review: us really like nuts little syrup crunchy tasty great value amazon price especially many almonds
# Original summary: great
# Predicted summary:  great product
#
#
# Review: love coconut milk nice thick thick use get semi sweet sugar added found great whole diets paleo best non dairy creamer coffee
# Original summary: best coconut milk ever
# Predicted summary:  love this gum
#
#
# Review: family started using product tired using chocolate sauce sorts artificial ingredients high fructose corn syrup tastes great feel like ingesting science experiment full ingredients cannot pronounce
# Original summary: no funny ingredients
# Predicted summary:  not good
#
#
# Review: best around seasoning ever msg lots flavor use fish chicken salads vegetables dressings eggs almost everything adds great seasoning recipes
# Original summary: best greek seasoning we have found
# Predicted summary:  great for cooking
#
#
# Review: awesome product must try sushi tastes like candy heaven food half fun experience making candy must
# Original summary: yum yum
# Predicted summary:  great product
#
#
# Review: really good different taste could see many people would like yes really like
# Original summary: really good
# Predicted summary:  great taste
#
#
# Review: made different company located ca definitely taste ghiradelli supposedly made ingredients would say recipe huge difference taste form kid thanks memories ghiradelli
# Original summary: not the same as ghiradelli
# Predicted summary:  not what expected
#
#
# Review: black licorice taste like artificial flavor nasty artificial black dye coat tongue teeth wonderfully soft chewy took box work everyone agreed best black licorice ever tasted
# Original summary: the best black licorice
# Predicted summary:  not bad
#
#
# Review: far best raisin bran available available say barely available good luck trying find else gone way tab soda mint tea everything else used wide barely holding
# Original summary: most wholesome authentic raisin bran
# Predicted summary:  great cereal
#
#
# Review: fast easy definitely delicious makes great cup coffee easy make good purchase continue order thanx
# Original summary: delish
# Predicted summary:  delicious
#
#
# Review: jam whole huckleberries sweet real treat us lost local huckleberry longer time jam brings back flavors thought long gone lovely bit christmas
# Original summary: bringing back old times
# Predicted summary:  great jerky
#
#
# Review: every week make waffles pancakes wife daughter opinion waffles taste different better make jiffy mix jiffy mix costs lot less likely order product
# Original summary: no better than jiffy
# Predicted summary:  great product
#
#
# Review: strong weak bitter perfect favorite coffee occasionally make one else cup nantucket blend always love try disappointed
# Original summary: the best cup ever
# Predicted summary:  great coffee
#
#
# Review: nothing beats taste yorkshire red wakes morning continues support day need things makes great iced tea best thing actually tastes like real tea bagged dust
# Original summary: world most delicious tea
# Predicted summary:  great tea
#
#
# Review: chips delicious delivered quickly perfect condition order wish option could choose flavors want
# Original summary: popchips delicious
# Predicted summary:  great chips
#
#
# Review: good quality aware potent apple butter turned quite taste add another apples cut taste
# Original summary: cinn oil
# Predicted summary:  good product
#
#
# Review: wafers good vanilla taste like real vanilla fake vanilla
# Original summary: vanilla wafers
# Predicted summary:  good taste
#
#
# Review: love gluten free cookie great tasting little snack kids cannot gluten like treat love fact portion reasonable bravo stars
# Original summary: awesome gf treat
# Predicted summary:  great gluten free snack
#
#
# Review: cook special ingredient one popular salads really goes well variety dishes salad makes special kick
# Original summary: really enjoyed this oil
# Predicted summary:  great product
#
#
# Review: love chipotle lot foods easy mess way add smokey chipotle cheddar crackers chili killer cream cheese log great added salt many brands include salt would rather add buy
# Original summary: good chipotle seasoning
# Predicted summary:  great product
#
#
# Review: purchased good price chihuahua likes subscription received tub however week later went line find subscription price gone notification sent inform price increase
# Original summary: great deal
# Predicted summary:  great product
#
#
# Review: coffee smells amazing brewed weak flavor aroma lost put anything hoping little boldness would recommend anyone likes medium dark roast coffee sorely disappointed
# Original summary: smells good
# Predicted summary:  not bad
#
#
# Review: sure difference flavours plain white barley tastes good stuff small bag grocery store wanted go organic amazon good price watch long cook think directions bag bit long tastes
# Original summary: good barley
# Predicted summary:  great product
#
#
# Review: love stuff getting almost impossible find anywhere crystal lite buy flavor overwhelming stain spill
# Original summary: why cannot get this anymore
# Predicted summary:  great product
#
#
# Review: make dark rye bread wife love occasionally find flour local grocery store lately harder find ordering online makes things much easier good quality flour keeps well freezer ready use
# Original summary: great stuff
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-6ed9055e1119> in <module>()
#       2     print("Review:",seq2text(x_tr[i]))
#       3     print("Original summary:",seq2summary(y_tr[i]))
# ----> 4     print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
#       5     print("\n")
#
# <ipython-input-67-219f1da445c8> in decode_sequence(input_seq)
#       1 def decode_sequence(input_seq):
#       2     # Encode the input as state vectors.
# ----> 3     e_out, e_h, e_c = encoder_model.predict(input_seq)
#       4
#       5     # Generate empty target sequence of length 1.
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1959           use_multiprocessing=use_multiprocessing,
#    1960           model=self,
# -> 1961           steps_per_execution=self._steps_per_execution)
#    1962
#    1963       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1397   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1398     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1399   return DataHandler(*args, **kwargs)
#    1400
#    1401
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1159         use_multiprocessing=use_multiprocessing,
#    1160         distribution_strategy=tf.distribute.get_strategy(),
# -> 1161         model=model)
#    1162
#    1163     strategy = tf.distribute.get_strategy()
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     324       return flat_dataset
#     325
# --> 326     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     327
#     328     dataset = self.slice_inputs(indices_dataset, inputs)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func, name)
#    2058       Dataset: A `Dataset`.
#    2059     """
# -> 2060     return FlatMapDataset(self, map_func, name=name)
#    2061
#    2062   def interleave(self,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, name)
#    5278     self._input_dataset = input_dataset
#    5279     self._map_func = structured_function.StructuredFunctionWrapper(
# -> 5280         map_func, self._transformation_name(), dataset=input_dataset)
#    5281     if not isinstance(self._map_func.output_structure, DatasetSpec):
#    5282       raise TypeError(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     269         fn_factory = trace_tf_function(defun_kwargs)
#     270
# --> 271     self._function = fn_factory()
#     272     # There is no graph to add in eager mode.
#     273     add_to_graph &= not context.executing_eagerly()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3069     """
#    3070     graph_function = self._get_concrete_function_garbage_collected(
# -> 3071         *args, **kwargs)
#    3072     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3073     return graph_function
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3034       args, kwargs = None, None
#    3035     with self._lock:
# -> 3036       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3037       seen_names = set()
#    3038       captured = object_identity.ObjectIdentitySet(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3290
#    3291           self._function_cache.add_call_context(cache_key.call_context)
# -> 3292           graph_function = self._create_graph_function(args, kwargs)
#    3293           self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                                    graph_function)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3138             arg_names=arg_names,
#    3139             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3140             capture_by_value=self._capture_by_value),
#    3141         self._function_attributes,
#    3142         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1159         _, original_func = tf_decorator.unwrap(python_func)
#    1160
# -> 1161       func_outputs = python_func(*func_args, **func_kwargs)
#    1162
#    1163       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapped_fn(*args)
#     246           attributes=defun_kwargs)
#     247       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 248         ret = wrapper_helper(*args)
#     249         ret = structure.to_tensor_list(self._output_structure, ret)
#     250         return [ops.convert_to_tensor(t) for t in ret]
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/structured_function.py in wrapper_helper(*args)
#     175       if not _should_unpack(nested_args):
#     176         nested_args = (nested_args,)
# --> 177       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     178       if _should_pack(ret):
#     179         ret = tuple(ret)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     687       try:
#     688         with conversion_ctx:
# --> 689           return converted_call(f, args, kwargs, options=options)
#     690       except Exception as e:  # pylint:disable=broad-except
#     691         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     456
#     457   if kwargs is not None:
# --> 458     return f(*args, **kwargs)
#     459   return f(*args)
#     460
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in slice_batch_indices(indices)
#     316       if self._partial_batch_size:
#     317         index_remainder = tf.data.Dataset.from_tensors(tf.slice(
# --> 318             indices, [num_in_full_batch], [self._partial_batch_size]))
#     319         flat_dataset = flat_dataset.concatenate(index_remainder)
#     320
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensors(tensors, name)
#     711       Dataset: A `Dataset`.
#     712     """
# --> 713     return TensorDataset(tensors, name=name)
#     714
#     715   @staticmethod
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, element, name)
#    4462         self._tensors,
#    4463         output_shapes=structure.get_flat_tensor_shapes(self._structure),
# -> 4464         metadata=self._metadata.SerializeToString())
#    4465     super(TensorDataset, self).__init__(variant_tensor)
#    4466
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in tensor_dataset(components, output_shapes, metadata, name)
#    7474   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    7475         "TensorDataset", components=components, output_shapes=output_shapes,
# -> 7476                          metadata=metadata, name=name)
#    7477   _result = _outputs[:]
#    7478   if _execute.must_record_gradient():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     366   inputs = []
#     367   input_types = []
# --> 368   with g.as_default(), ops.name_scope(name) as scope:
#     369
#     370     # Perform input type inference
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in __enter__(self)
#    6795     try:
#    6796       self._name_scope = g.name_scope(self._name)
# -> 6797       return self._name_scope.__enter__()
#    6798     except:
#    6799       if self._g_manager is not None:
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in name_scope(self, name)
#    4506     else:
#    4507       new_stack = self.unique_name(name)
# -> 4508       returned_scope = new_stack + "/"
#    4509     self._name_stack = new_stack
#    4510     try:
#
# KeyboardInterrupt:
